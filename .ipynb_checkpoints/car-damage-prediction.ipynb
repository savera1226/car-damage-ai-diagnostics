# %% [markdown]
# <h2 align="center">Vehicle Damage Detection Project</h2>

# %%
import os
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import time
import torchvision.models as models
from matplotlib import pyplot as plt

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %% [markdown]
# ### Load Data

# %%
image_transforms = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(10),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.2),
    transforms.Resize((224,224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# %%
dataset_path = '/kaggle/input/car-images-defective-dataset'

dataset = datasets.ImageFolder(root=dataset_path, transform=image_transforms)

print(f'✅ Success! Total images: {len(dataset)}')
print(f'✅ Classes detected: {dataset.classes}')
# Out:
# ✅ Success! Total images: 2378
# ✅ Classes detected: ['F_Breakage', 'F_Crushed', 'F_Normal', 'R_Breakage', 'R_Crushed', 'R_Normal']

# %%
dataset.classes
# Out:
# ['F_Breakage', 'F_Crushed', 'F_Normal', 'R_Breakage', 'R_Crushed', 'R_Normal']

# %%
num_classes = len(dataset.classes)
num_classes
# Out:
# 6

# %%
train_size = int(0.75*len(dataset))
val_size = len(dataset) - train_size
train_size,val_size
# Out:
# (1783, 595)

# %%
from torch.utils.data import random_split
train_dataset, val_dataset = random_split(dataset, [train_size, val_size])

# %%
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=True)

# %%
for images, labels in train_loader:
    print(images.shape, labels.shape)
    break
# Out:
# torch.Size([32, 3, 224, 224]) torch.Size([32])

# %%
labels[0]
# Out:
# tensor(0)

# %%
images[0].shape
# Out:
# torch.Size([3, 224, 224])

# %%
images[0].permute(1,2,0).shape
# Out:
# torch.Size([224, 224, 3])

# %%
# Define mean and std from your image_transforms for easier denormalization
mean_vals = torch.tensor([0.485, 0.456, 0.406]).view(3, 1, 1)
std_vals = torch.tensor([0.229, 0.224, 0.225]).view(3, 1, 1)

# %%
# Denormalize the image using the explicitly defined mean_vals and std_vals
denormalized_image = images[0] * std_vals + mean_vals

# Permute and display
plt.imshow(denormalized_image.permute(1,2,0))
plt.title(f'Label: {dataset.classes[labels[0]]}') # Add a title with the class name
plt.axis('off') # Hide axes for cleaner display
plt.show()

# %%
import matplotlib.pyplot as plt

# Create a dictionary to store one image per class
class_samples = {}
for img, label in dataset:
    if label not in class_samples:
        class_samples[label] = img
    if len(class_samples) == 6:
        break

# Plotting
plt.figure(figsize=(15, 10))
for i, (label_idx, img_tensor) in enumerate(sorted(class_samples.items())):
    plt.subplot(2, 3, i + 1)
    
    # Your denormalization logic
    img_show = img_tensor.permute(1, 2, 0)
    img_show = img_show * torch.tensor([0.229, 0.224, 0.225]) + torch.tensor([0.485, 0.456, 0.406])
    img_show = img_show.clamp(0, 1) # Ensure values are in valid 0-1 range
    
    plt.imshow(img_show)
    plt.title(dataset.classes[label_idx])
    plt.axis('off')
plt.show()

# %% [markdown]
# ### Model 1: CNN

# %%
class CarClassifierCNN(nn.Module):
  def __init__(self,num_classes):
    super().__init__()
    self.network = nn.Sequential(

        # LAYER 1: Look for SIMPLE patterns (edges, corners)
        nn.Conv2d(in_channels=3, out_channels=16, kernel_size=3, stride = 1,padding=1), # (16,224,224)
        nn.ReLU(),
        nn.MaxPool2d(kernel_size=2, stride=2,padding=0), #(16,112,112)

        # LAYER 2: Look for COMPLEX patterns (wheels, windows)
        nn.Conv2d(in_channels=16, out_channels=32, kernel_size=3, stride = 1,padding=1), # (16,112,112)
        nn.ReLU(),
        nn.MaxPool2d(kernel_size=2, stride=2,padding=0), #(32,56,56)

        # LAYER 3: Look for VERY COMPLEX patterns (damage shapes)
        nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3, stride = 1,padding=1),
        nn.ReLU(),
        nn.MaxPool2d(kernel_size=2, stride=2,padding=0), #(64,28,28)

        # Flatten: Convert 3D → 1D (like unfolding a cube)
        nn.Flatten(),

        # Decision layers
        nn.Linear(64*28*28, 512),
        nn.ReLU(),
        nn.Linear(512,num_classes)
)

  def forward(self, x):
    x = self.network(x)
    return x

# %%
# Instantiate the model, loss function, and optimizer
model = CarClassifierCNN(num_classes=num_classes).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
def train_model(model, criterion, optimizer, epochs=5):
    start = time.time()

    for epoch in range(epochs):
        model.train()
        running_loss = 0.0
        for batch_num, (images, labels) in enumerate(train_loader):
            images, labels = images.to(device), labels.to(device)

            # Zero the parameter gradients
            optimizer.zero_grad()

            # Forward pass
            outputs = model(images)
            loss = criterion(outputs, labels)

            # Backward pass and optimization
            loss.backward()
            optimizer.step()

            if (batch_num+1) % 10 == 0:
                print(f"Batch: {batch_num+1}, Epoch: {epoch+1}, Loss: {loss.item():0.2f}")

            running_loss += loss.item() * images.size(0)

        epoch_loss = running_loss / len(train_loader.dataset)
        print(f"Epoch [{epoch+1}/{epochs}], Avg Loss: {epoch_loss:.4f}")

        # Validation
        model.eval()
        correct = 0
        total = 0
        all_labels = []
        all_predictions = []

        with torch.no_grad():
            for images, labels in val_loader:
                images, labels = images.to(device), labels.to(device)
                outputs = model(images)
                _, predicted = torch.max(outputs.data,1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()
                all_labels.extend(labels.cpu().numpy())
                all_predictions.extend(predicted.cpu().numpy())

            print(f"*** Validation Accuracy: {100 * correct / total:.2f}% ***")

    end = time.time()
    print(f"Execution time: {end - start} seconds")

    return all_labels, all_predictions

# %%
all_labels, all_predictions = train_model(model, criterion, optimizer, epochs=10)
# Out:
# Batch: 10, Epoch: 1, Loss: 1.80
# Batch: 20, Epoch: 1, Loss: 1.77
# Batch: 30, Epoch: 1, Loss: 1.69
# Batch: 40, Epoch: 1, Loss: 1.64
# Batch: 50, Epoch: 1, Loss: 1.62
# Epoch [1/10], Avg Loss: 1.7863
# *** Validation Accuracy: 41.18% ***
# Batch: 10, Epoch: 2, Loss: 1.63
# Batch: 20, Epoch: 2, Loss: 1.34
# Batch: 30, Epoch: 2, Loss: 1.36
# Batch: 40, Epoch: 2, Loss: 1.43
# Batch: 50, Epoch: 2, Loss: 1.19
# Epoch [2/10], Avg Loss: 1.3524
# *** Validation Accuracy: 50.92% ***
# Batch: 10, Epoch: 3, Loss: 1.15
# Batch: 20, Epoch: 3, Loss: 1.25
# Batch: 30, Epoch: 3, Loss: 1.17
# Batch: 40, Epoch: 3, Loss: 1.07
# Batch: 50, Epoch: 3, Loss: 1.02
# Epoch [3/10], Avg Loss: 1.2219
# *** Validation Accuracy: 52.61% ***
# Batch: 10, Epoch: 4, Loss: 1.03
# Batch: 20, Epoch: 4, Loss: 0.95
# Batch: 30, Epoch: 4, Loss: 1.00
# Batch: 40, Epoch: 4, Loss: 1.17
# Batch: 50, Epoch: 4, Loss: 0.82
# Epoch [4/10], Avg Loss: 1.1394
# *** Validation Accuracy: 51.93% ***
# Batch: 10, Epoch: 5, Loss: 1.31
# ...

# %% [markdown]
# ### Model 2: CNN with Regularization

# %%
class CarClassifierCNNWithRegularization(nn.Module):
    def __init__(self, num_classes):
        super().__init__()
        self.network = nn.Sequential(
            nn.Conv2d(in_channels=3, out_channels=16, kernel_size=3, stride=1, padding=1), # (16, 224, 224)
            nn.BatchNorm2d(16),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2, padding=0), # (16, 112, 112),
            nn.Conv2d(in_channels=16, out_channels=32, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2, padding=0), # (32, 56, 56)
            nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2, padding=0), # (64, 28, 28),
            nn.Flatten(),
            nn.Linear(64*28*28, 512),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(512, num_classes)
        )

    def forward(self, x):
        x = self.network(x)
        return x

# %%
model = CarClassifierCNNWithRegularization(num_classes=num_classes).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-4)

all_labels, all_predictions = train_model(model, criterion, optimizer,  epochs=10)
# Out:
# Batch: 10, Epoch: 1, Loss: 15.64
# Batch: 20, Epoch: 1, Loss: 4.55
# Batch: 30, Epoch: 1, Loss: 1.69
# Batch: 40, Epoch: 1, Loss: 1.43
# Batch: 50, Epoch: 1, Loss: 1.48
# Epoch [1/10], Avg Loss: 6.6422
# *** Validation Accuracy: 39.83% ***
# Batch: 10, Epoch: 2, Loss: 1.33
# Batch: 20, Epoch: 2, Loss: 1.40
# Batch: 30, Epoch: 2, Loss: 1.28
# Batch: 40, Epoch: 2, Loss: 1.51
# Batch: 50, Epoch: 2, Loss: 1.34
# Epoch [2/10], Avg Loss: 1.4655
# *** Validation Accuracy: 44.87% ***
# Batch: 10, Epoch: 3, Loss: 1.49
# Batch: 20, Epoch: 3, Loss: 1.22
# Batch: 30, Epoch: 3, Loss: 1.38
# Batch: 40, Epoch: 3, Loss: 1.57
# Batch: 50, Epoch: 3, Loss: 1.14
# Epoch [3/10], Avg Loss: 1.4516
# *** Validation Accuracy: 43.53% ***
# Batch: 10, Epoch: 4, Loss: 1.30
# Batch: 20, Epoch: 4, Loss: 1.37
# Batch: 30, Epoch: 4, Loss: 1.35
# Batch: 40, Epoch: 4, Loss: 1.38
# Batch: 50, Epoch: 4, Loss: 1.64
# Epoch [4/10], Avg Loss: 1.3770
# *** Validation Accuracy: 47.73% ***
# Batch: 10, Epoch: 5, Loss: 1.29
# ...

# %% [markdown]
# ### Model 3: Transfer Learning with EfficientNet

# %%
model = models.efficientnet_b0(weights='DEFAULT')
model.classifier[1].in_features
# Out:
# Downloading: "https://download.pytorch.org/models/efficientnet_b0_rwightman-7f5810bc.pth" to /root/.cache/torch/hub/checkpoints/efficientnet_b0_rwightman-7f5810bc.pth
# 100%|██████████| 20.5M/20.5M [00:00<00:00, 156MB/s]
# 1280

# %%
class CarClassifierEfficientNet(nn.Module):
    def __init__(self, num_classes):
        super().__init__()
        self.model = models.efficientnet_b0(weights='DEFAULT')
        
        for param in self.model.parameters():
            param.requires_grad = False
        
        in_features = self.model.classifier[1].in_features
        
        self.model.classifier = nn.Sequential(
            nn.Dropout(0.5),
            nn.Linear(in_features, num_classes)
        )
        
    def forward(self, x):
        x = self.model(x)
        return x

# %%
model = CarClassifierEfficientNet(num_classes=num_classes).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(filter(lambda p: p.requires_grad, model.parameters()), lr=0.001)

all_labels, all_predictions = train_model(model, criterion, optimizer, epochs=10)
# Out:
# Batch: 10, Epoch: 1, Loss: 1.64
# Batch: 20, Epoch: 1, Loss: 1.55
# Batch: 30, Epoch: 1, Loss: 1.56
# Batch: 40, Epoch: 1, Loss: 1.33
# Batch: 50, Epoch: 1, Loss: 1.35
# Epoch [1/10], Avg Loss: 1.5060
# *** Validation Accuracy: 55.29% ***
# Batch: 10, Epoch: 2, Loss: 1.26
# Batch: 20, Epoch: 2, Loss: 1.26
# Batch: 30, Epoch: 2, Loss: 1.21
# Batch: 40, Epoch: 2, Loss: 0.96
# Batch: 50, Epoch: 2, Loss: 0.97
# Epoch [2/10], Avg Loss: 1.1732
# *** Validation Accuracy: 64.71% ***
# Batch: 10, Epoch: 3, Loss: 0.90
# Batch: 20, Epoch: 3, Loss: 1.19
# Batch: 30, Epoch: 3, Loss: 0.95
# Batch: 40, Epoch: 3, Loss: 0.89
# Batch: 50, Epoch: 3, Loss: 0.86
# Epoch [3/10], Avg Loss: 1.0761
# *** Validation Accuracy: 63.53% ***
# Batch: 10, Epoch: 4, Loss: 0.98
# Batch: 20, Epoch: 4, Loss: 1.01
# Batch: 30, Epoch: 4, Loss: 1.16
# Batch: 40, Epoch: 4, Loss: 1.05
# Batch: 50, Epoch: 4, Loss: 0.98
# Epoch [4/10], Avg Loss: 1.0171
# *** Validation Accuracy: 65.55% ***
# Batch: 10, Epoch: 5, Loss: 1.13
# ...

# %% [markdown]
# ### Model 4: Transfer Learning with ResNet

# %%
# Load the pre-trained ResNet model
class CarClassifierResNet(nn.Module):
    def __init__(self, num_classes, dropout_rate=0.5):
        super().__init__()
        self.model = models.resnet50(weights='DEFAULT')
        # Freeze all layers except the final fully connected layer
        for param in self.model.parameters():
            param.requires_grad = False
            
        # Unfreeze layer4 and fc layers
        for param in self.model.layer4.parameters():
            param.requires_grad = True            
            
        # Replace the final fully connected layer
        self.model.fc = nn.Sequential(
            nn.Dropout(dropout_rate),
            nn.Linear(self.model.fc.in_features, num_classes)
        )

    def forward(self, x):
        x = self.model(x)
        return x

# %%
model = CarClassifierResNet(num_classes=num_classes).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(filter(lambda p: p.requires_grad, model.parameters()), lr=0.001)

labels, predictions = train_model(model, criterion, optimizer, epochs=10)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-11ad3fa6.pth" to /root/.cache/torch/hub/checkpoints/resnet50-11ad3fa6.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 195MB/s]
# Batch: 10, Epoch: 1, Loss: 0.98
# Batch: 20, Epoch: 1, Loss: 0.92
# Batch: 30, Epoch: 1, Loss: 0.70
# Batch: 40, Epoch: 1, Loss: 0.59
# Batch: 50, Epoch: 1, Loss: 0.91
# Epoch [1/10], Avg Loss: 0.9192
# *** Validation Accuracy: 68.24% ***
# Batch: 10, Epoch: 2, Loss: 0.49
# Batch: 20, Epoch: 2, Loss: 0.61
# Batch: 30, Epoch: 2, Loss: 0.68
# Batch: 40, Epoch: 2, Loss: 0.29
# Batch: 50, Epoch: 2, Loss: 0.33
# Epoch [2/10], Avg Loss: 0.5162
# *** Validation Accuracy: 80.34% ***
# Batch: 10, Epoch: 3, Loss: 0.42
# Batch: 20, Epoch: 3, Loss: 0.21
# Batch: 30, Epoch: 3, Loss: 0.20
# Batch: 40, Epoch: 3, Loss: 0.27
# Batch: 50, Epoch: 3, Loss: 0.32
# Epoch [3/10], Avg Loss: 0.3739
# *** Validation Accuracy: 78.82% ***
# Batch: 10, Epoch: 4, Loss: 0.44
# Batch: 20, Epoch: 4, Loss: 0.22
# ...

# %% [markdown]
# #### I ran hyperparameter tunning in another notebook and figured that the best parameters for resnet models are (1) Dropout rate = 0.2 (2) Learning Rate = 0.005
#
# So now let's train the model once again with these best parameters

# %%
model = CarClassifierResNet(num_classes=num_classes, dropout_rate=0.2).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(filter(lambda p: p.requires_grad, model.parameters()), lr=0.005)

labels, predictions = train_model(model, criterion, optimizer, epochs=10)
# Out:
# Batch: 10, Epoch: 1, Loss: 0.86
# Batch: 20, Epoch: 1, Loss: 1.01
# Batch: 30, Epoch: 1, Loss: 0.93
# Batch: 40, Epoch: 1, Loss: 0.75
# Batch: 50, Epoch: 1, Loss: 0.62
# Epoch [1/10], Avg Loss: 0.9301
# *** Validation Accuracy: 71.60% ***
# Batch: 10, Epoch: 2, Loss: 0.35
# Batch: 20, Epoch: 2, Loss: 0.68
# Batch: 30, Epoch: 2, Loss: 0.68
# Batch: 40, Epoch: 2, Loss: 0.35
# Batch: 50, Epoch: 2, Loss: 0.40
# Epoch [2/10], Avg Loss: 0.5211
# *** Validation Accuracy: 73.61% ***
# Batch: 10, Epoch: 3, Loss: 0.58
# Batch: 20, Epoch: 3, Loss: 0.32
# Batch: 30, Epoch: 3, Loss: 0.58
# Batch: 40, Epoch: 3, Loss: 0.36
# Batch: 50, Epoch: 3, Loss: 0.50
# Epoch [3/10], Avg Loss: 0.4077
# *** Validation Accuracy: 77.65% ***
# Batch: 10, Epoch: 4, Loss: 0.36
# Batch: 20, Epoch: 4, Loss: 0.25
# Batch: 30, Epoch: 4, Loss: 0.36
# Batch: 40, Epoch: 4, Loss: 0.38
# Batch: 50, Epoch: 4, Loss: 0.31
# Epoch [4/10], Avg Loss: 0.3578
# *** Validation Accuracy: 75.80% ***
# Batch: 10, Epoch: 5, Loss: 0.19
# ...

# %% [markdown]
# ### Model Evaluation using Confusion Matrix and Classification Report

# %%
from sklearn.metrics import classification_report

report = classification_report(labels, predictions)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.80      0.83       125
#            1       0.72      0.77      0.74       115
#            2       0.88      0.84      0.86       129
#            3       0.68      0.76      0.72        72
#            4       0.75      0.69      0.72        86
#            5       0.77      0.84      0.80        68
#
#     accuracy                           0.78       595
#    macro avg       0.78      0.78      0.78       595
# weighted avg       0.79      0.78      0.79       595

# %%
import numpy as np
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from matplotlib import pyplot as plt
class_names = ['F_Breakage', 'F_Crushed', 'F_Normal', 'R_Breakage', 'R_Crushed', 'R_Normal']

conf_matrix = confusion_matrix(labels, predictions, labels=np.arange(num_classes))
disp = ConfusionMatrixDisplay(confusion_matrix=conf_matrix, display_labels=class_names)
disp.plot(cmap=plt.cm.Blues, xticks_rotation=45)
plt.title("Confusion Matrix for Vehicle Damage Classification")
plt.show()

# %% [markdown]
# ### Save the Model

# %%
torch.save(model.state_dict(), 'saved_model.pth')
